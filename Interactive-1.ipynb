# %% [markdown]
# Connected to rnn (Python 3.12.7)

# %%
#dpath = path1 + '/UNITY/data_out_real/L_bh'

#m_tag0 = "mice1"
m_tag0 = "mice_gcamp"
#tag1 = 'L'
tag1 = 'L'

m_tag = m_tag0 + ' ' + tag1

dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
dpath2 = dpath + tag1 +'/'

flist, ftimes = f_load_fnames(dpath2)
params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')

#df_save = pd.DataFrame(flist)
#df_save.to_csv(dpath + '//../RL_data.csv', index=False)


bh_data = []
                                                
for ftag in flist:
    
    bh_data_slice = f_load_bh_data(dpath2, ftag, params_xls)
    bh_data.append(bh_data_slice)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
#      13 dpath2 = dpath + tag1 +'/'
# ---> 15 flist, ftimes = f_load_fnames(dpath2)
#      16 params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')
#      18 #df_save = pd.DataFrame(flist)
#      19 #df_save.to_csv(dpath + '//../RL_data.csv', index=False)
#
# NameError: name 'f_load_fnames' is not defined

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Sep 15 11:26:21 2025

@author: ys2605
"""

import sys
import os

for user1 in ['ys2605', 'shymk']:
    if os.path.isdir('C:/Users/' + user1):
        path1 = 'C:/Users/' + user1 + '/Desktop/stuff/VR/VR_analysis/'

sys.path.append(path1)
sys.path.append(path1 + '/functions')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 22
#      19 import pandas as pd
#      20 import matplotlib.pyplot as plt
# ---> 22 from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session
#
# ImportError: cannot import name 'f_plot_vertical_ov_time' from 'f_functions' (C:\Users/ys2605/Desktop/stuff/VR/VR_analysis//functions\f_functions.py)

# %%
print(1)
# Out:
# 1

# %% [markdown]
# No kernel connected

# %% [markdown]
# Connected to rnn (Python 3.12.7)

# %%
#dpath = path1 + '/UNITY/data_out_real/L_bh'

#m_tag0 = "mice1"
m_tag0 = "mice_gcamp"
#tag1 = 'L'
tag1 = 'L'

m_tag = m_tag0 + ' ' + tag1

dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
dpath2 = dpath + tag1 +'/'

flist, ftimes = f_load_fnames(dpath2)
params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')

#df_save = pd.DataFrame(flist)
#df_save.to_csv(dpath + '//../RL_data.csv', index=False)


bh_data = []
                                                
for ftag in flist:
    
    bh_data_slice = f_load_bh_data(dpath2, ftag, params_xls)
    bh_data.append(bh_data_slice)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
#      13 dpath2 = dpath + tag1 +'/'
# ---> 15 flist, ftimes = f_load_fnames(dpath2)
#      16 params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')
#      18 #df_save = pd.DataFrame(flist)
#      19 #df_save.to_csv(dpath + '//../RL_data.csv', index=False)
#
# NameError: name 'f_load_fnames' is not defined

# %%
path1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 path1
#
# NameError: name 'path1' is not defined

# %%
import sys
import os

# %%
for user1 in ['ys2605', 'shymk']:
    if os.path.isdir('C:/Users/' + user1):
        path1 = 'C:/Users/' + user1 + '/Desktop/stuff/VR/VR_analysis/'

# %%
path1
# Out:
# 'C:/Users/ys2605/Desktop/stuff/VR/VR_analysis/'

# %%
sys.path.append(path1)
sys.path.append(path1 + '/functions')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session
#
# ImportError: cannot import name 'f_plot_vertical_ov_time' from 'f_functions' (C:\Users/ys2605/Desktop/stuff/VR/VR_analysis//functions\f_functions.py)

# %%
path1 + '/functions'
# Out:
# 'C:/Users/ys2605/Desktop/stuff/VR/VR_analysis//functions'

# %%
from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time #, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session

# %%
from f_functions import f_load_fnames, f_load_bh_data, f_get_session_data, f_plot_session2, f_proc_movement, f_proc_lick_rew, f_proc_lick_rew_df, f_spheric_to_cart, f_cart_to_spheric_np, f_comp_FOV_adj, f_plot_monitor_outline, f_plot_lateral_over_time #, f_plot_vertical_ov_time, f_plot_dist_ov_time # f_plot_session

# %%
#m_tag0 = "mice1"
m_tag0 = "mice_gcamp"
#tag1 = 'L'
tag1 = 'L'

# %%
#m_tag0 = "mice1"
m_tag0 = "mice_gcamp"
#tag1 = 'L'
tag1 = 'L'

m_tag = m_tag0 + ' ' + tag1

dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
dpath2 = dpath + tag1 +'/'

flist, ftimes = f_load_fnames(dpath2)
params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')

# %%
#dpath = path1 + '/UNITY/data_out_real/L_bh'

#m_tag0 = "mice1"
m_tag0 = "mice_gcamp"
#tag1 = 'L'
tag1 = 'L'

m_tag = m_tag0 + ' ' + tag1

dpath = 'F:/VR/Bh_data/' + m_tag0 + '/'
dpath2 = dpath + tag1 +'/'

flist, ftimes = f_load_fnames(dpath2)
params_xls = pd.read_excel(dpath + tag1 + '_params.xlsx')

#df_save = pd.DataFrame(flist)
#df_save.to_csv(dpath + '//../RL_data.csv', index=False)


bh_data = []
                                                
for ftag in flist:
    
    bh_data_slice = f_load_bh_data(dpath2, ftag, params_xls)
    bh_data.append(bh_data_slice)
